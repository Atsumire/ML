# %% [markdown]
# <a href="https://colab.research.google.com/github/Letch49/ML-vvsu-2025/blob/feature/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # МЛ Практика 1

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = 'heart.csv' # Загрузка набора данных

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# Вывод первых 5 строк
df.head()
# Out:
#    AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0      42      1     110      65     64    147      291    2          8
# 1      53      1     130      72     69    167      278    1          6
# 2      53      2     120      90     70    222      342    4          8
# 3      48      4     120      80     72    229      239    4          8
# 4      53      3     118      74     66    134      243    3          8
#
#    MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# 0      4     120      78      271    146       2      1
# 1      2     122      68      250    165       9      1
# 2      1     132      90      304    223       2      1
# 3      2     118      68      209    227       3      1
# 4      5     118      56      261    138       2      1

# %%
# Информация о наборе данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AGE_50     200 non-null    int64
#  1   MD_50      200 non-null    int64
#  2   SBP_50     200 non-null    int64
#  3   DBP_50     200 non-null    int64
#  4   HT_50      200 non-null    int64
#  5   WT_50      200 non-null    int64
#  6   CHOL_50    200 non-null    int64
#  7   SES        200 non-null    int64
#  8   CL_STATUS  200 non-null    int64
#  9   MD_62      200 non-null    int64
#  10  SBP_62     200 non-null    int64
#  11  DBP_62     200 non-null    int64
#  12  CHOL_62    200 non-null    int64
#  13  WT_62      200 non-null    int64
#  14  IHD_DX     200 non-null    int64
#  15  DEATH      200 non-null    int64
# dtypes: int64(16)
# memory usage: 25.1 KB

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['AGE_50', 'MD_50', 'SBP_50', 'DBP_50', 'HT_50', 'WT_50', 'CHOL_50',
#        'SES', 'CL_STATUS', 'MD_62', 'SBP_62', 'DBP_62', 'CHOL_62', 'WT_62',
#        'IHD_DX', 'DEATH'],
#       dtype='object')

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0        42      1     110      65     64    147      291    2          8
# 1        53      1     130      72     69    167      278    1          6
# 2        53      2     120      90     70    222      342    4          8
# 3        48      4     120      80     72    229      239    4          8
# 4        53      3     118      74     66    134      243    3          8
# ..      ...    ...     ...     ...    ...    ...      ...  ...        ...
# 195      50      1     115      80     66    148      300    2          8
# 196      23      1     110      70     69    137      120    3          8
# 197      20      3     130      80     66    150      210    5          0
# 198      46      3     140      84     66    138      130    4          6
# 199      36      1     100      70     70    157      260    3          8
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# ...

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# AGE_50       int64
# MD_50        int64
# SBP_50       int64
# DBP_50       int64
# HT_50        int64
# WT_50        int64
# CHOL_50      int64
# SES          int64
# CL_STATUS    int64
# MD_62        int64
# SBP_62       int64
# DBP_62       int64
# CHOL_62      int64
# WT_62        int64
# IHD_DX       int64
# DEATH        int64
# dtype: object

# %% [markdown]
# <pre>AGE_50 – Возраст человека.
# MD_50 – Медицинский диагноз или индекс здоровья.
# SBP_50 – Систолическое артериальное давление (systolic blood pressure) .
# DBP_50 – Диастолическое артериальное давление (diastolic blood pressure).
# HT_50 – Рост (height).
# WT_50 – Вес (weight).
# CHOL_50 – Уровень холестерина (cholesterol).
# SES – Социально-экономический статус (socioeconomic status).
# CL_STATUS – Клинический статус (возможно, индикатор состояния здоровья или наличия хронических заболеваний).
# MD_62 – Медицинский диагноз или индекс здоровья.
# SBP_62 – Систолическое артериальное давление.
# DBP_62 – Диастолическое артериальное давление.
# CHOL_62 – Уровень холестерина.
# WT_62 – Вес.
# IHD_DX – Диагноз ишемической болезни сердца (ischemic heart disease diagnosis).
# DEATH – Индикатор смерти (возможно, "1" означает смерть, "0" — нет).</pre>

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 2. **Определите, какие переменные являются непрерывными, а какие дискретными:**
#
#    - **Непрерывные переменные:** могут принимать любое значение в диапазоне.
#    - **Дискретные переменные:** принимают только определенные значения (обычно целые числа).
#
#    **Ваши ответы:**
#
#    - **Непрерывные переменные:**
#      - ` SBP_50', DBP_50, HT_50, WT_50, SBP_62, DBP_62, CHOL_50, CHOL_62, WT_62` ⏰
#
#    - **Дискретные переменные:**
#      - `'AGE_50, MD_50, SES, CL_STATUS, MD_62, IHD_DX, DEATH` ⏰

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# AGE_50: 45 уникальных значений
# MD_50: 4 уникальных значений
# SBP_50: 38 уникальных значений
# DBP_50: 31 уникальных значений
# HT_50: 15 уникальных значений
# WT_50: 92 уникальных значений
# CHOL_50: 94 уникальных значений
# SES: 5 уникальных значений
# CL_STATUS: 7 уникальных значений
# MD_62: 5 уникальных значений
# SBP_62: 55 уникальных значений
# DBP_62: 32 уникальных значений
# CHOL_62: 123 уникальных значений
# WT_62: 92 уникальных значений
# IHD_DX: 10 уникальных значений
# DEATH: 2 уникальных значений

# %% [markdown]
# 3. **Посмотрите на статистические показатели и сделайте выводы о распределении переменных:**

# %%
# Статистический разбор
df.describe()
# Out:
#           AGE_50       MD_50      SBP_50      DBP_50       HT_50       WT_50  \
# count  200.00000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    46.06500    2.360000  124.700000   83.380000   68.160000  168.075000
# std     10.81274    1.017633   18.114654   11.000484    2.768161   26.639589
# min     20.00000    1.000000   88.000000   38.000000   61.000000  109.000000
# 25%     38.00000    1.000000  110.000000   78.000000   66.000000  147.000000
# 50%     47.00000    2.000000  120.000000   80.000000   68.000000  165.000000
# 75%     54.00000    3.000000  130.000000   90.000000   70.000000  189.000000
# max     69.00000    4.000000  210.000000  140.000000   75.000000  245.000000
#
#           CHOL_50         SES   CL_STATUS       MD_62      SBP_62      DBP_62  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   258.105000    2.915000    7.650000    2.315000  141.480000   84.820000
# ...

# %% [markdown]
#    **Ваши наблюдения:**
#
#    ВАЖНО! ⏰
#    **```тут пишем много текста почему мы так считаем, пойдет даже (ну я вижу там всего 4 уникальных значения, скорее всего категориальное ИЛИ ну там числа дробные, вероятно числоая переменная```**

# %% [markdown]
# ```Медиана практически всех показателей примерно равна среднему арифметическому. 25% пациентов моложе 38-ми, 50% пациентов моложе 47-ми, 75% пациентов моложе 54-х. 75% людей имеют средний социально-экономический статус - 3. Большинство пациентов не умерли. Большинство людей в имеют нормальное или слегка-повышенное артериальное давление. Большинство пациентов имеет один клинический статус ```

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовой переменной `AGE_50`:**

# %%
sns.histplot(df['AGE_50'], kde=True)
plt.title('Распределение возраста')
plt.xlabel('Age')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# 2. **Гистограмма для числовой переменной `HT_50`:**

# %%
sns.histplot(df['HT_50'], kde=True)
plt.title('Распределение роста')
plt.xlabel('Рост')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# 3. **Гистограмма для числовых переменных `WT_50` и `WT_65`:**

# %%
sns.histplot(df['WT_50'], kde=True)
plt.title('Распределение веса')
plt.xlabel('Age')
plt.ylabel('Частота')
plt.show()

sns.histplot(df['WT_62'], kde=True)
plt.title('Распределение веса')
plt.xlabel('Age')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# 4. **Столбчатая диаграмма для категориальных переменных `MD_50` и `MD_62`:**

# %%
sns.countplot(x='MD_50', data=df)
plt.title('Распределение индекса здоровья 50')
plt.xlabel('Индекс здоровья')
plt.ylabel('Количество')
plt.show()
sns.countplot(x='MD_62', data=df)
plt.title('Распределение индекса здоровья 62')
plt.xlabel('Индекс здоровья')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# 5. **Столбчатая диаграмма для категориальной переменной `SES`:**

# %%
sns.countplot(x='SES', data=df)
plt.title('Распределение социально-экономического статуса')
plt.xlabel('Статус')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# 6. **Столбчатая диаграмма для категориальной переменной `CL_STATUS`:**

# %%
sns.countplot(x='CL_STATUS', data=df)
plt.title('Клинический статус')
plt.xlabel('Статус')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# 7. **Столбчатая диаграмма для категориальной переменной `DEATH`:**

# %%
sns.countplot(x='DEATH', data=df)
plt.title('Смертность')
plt.xlabel('Статус')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# 8. **Боксплот для числовой переменной `IHD_DX`:**

# %%
sns.boxplot(x='IHD_DX', data=df)
plt.title('Диагноз ишемической болезни сердца')
plt.xlabel('Статус')
plt.show()

# %% [markdown]
# 9. **Боксплот для числовых переменных `SBP_50` и `SBP_62`:**

# %%
sns.boxplot(x='SBP_50', data=df)
plt.title('Систолическое артериальное давление 50')
plt.xlabel('Давление')
# plt.ylabel('Давление')
plt.show()

sns.boxplot(x='SBP_62', data=df)
plt.title('Систолическое артериальное давление 62')
plt.xlabel('Давление')
# plt.ylabel('Давление')
plt.show()

# %% [markdown]
# 9. **Боксплот для числовых переменных `DBP_50` и `DBP_62`:**

# %%
sns.boxplot(x='DBP_50', data=df)
plt.title('Диастолическое  артериальное давление 50')
plt.xlabel('Давление')
# plt.ylabel('Давление')
plt.show()

sns.boxplot(x='DBP_62', data=df)
plt.title('Диастолическое артериальное давление 62')
plt.xlabel('Давление')
# plt.ylabel('Давление')
plt.show()

# %% [markdown]
# 9. **Боксплот для числовых переменных `CHOL_50` и `CHOL_62`:**

# %%
sns.boxplot(x='CHOL_50', data=df)
plt.title('Уровень холестирина')
plt.xlabel('Уровень')
# plt.ylabel('Давление')
plt.show()

sns.boxplot(x='CHOL_62', data=df)
plt.title('Уровень холестирина')
plt.xlabel('Уровень')
# plt.ylabel('Давление')
plt.show()

# %% [markdown]
#    **Ваши наблюдения:**
#
#    ВАЖНО! ⏰
#    **```тут пишем много текста почему мы так считаем, пойдет даже (Распределение по алкоголю сосредоточено не как нормальное распределение (alcohol), в среднем большинство значений в районе 6 (quality) ) ИЛИ на box plot chlorides видно много выбросов и медиана сосредоточена между 0 и 1``` **
#
#    p.s. если знаете контекст, то можете описать

# %% [markdown]
# ```# Большая часть пациентов находится в возрасте от 40 до 60 лет. Переменные WT_50 и WT_62 имеют похожее распределение. Распределение индекса здоровья в 50 лет 62 года существенно отличаются. С возрастом разброс диастолического артериального давления увеличился.  Уровень холестерина у пациентов в целом повысился. Уровень систолического артериального давления также в целом повысился. В выборке преобладают пациенты с клиническим статусом 8. Выживаемость пациентов более чем в два раза превышает смертность. Большая часть пациентов не имеет ишемичекой болезни сердца```

# %% [markdown]
# ## **5. Дополнительное задание** ⏰ (не обязательное, но полезное)
#
# ### **Описание:**
# Для тех, кто хочет углубить свои знания и навыки, выполните дополнительное задание ниже.
#
# ### **Задание:**

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# Корреляционная матрица
correlation_matrix = df.corr()

# Визуализация тепловой карты
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')

plt.title('Корреляционная матрица')
plt.show()

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('type', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# 2. **Интерпретируйте полученную корреляционную матрицу:**
#
#    - Какие переменные имеют сильную положительную корреляцию?
#    - Какие переменные имеют сильную отрицательную корреляцию?
#    - Какие переменные практически некоррелированы?
#
#    **Ваши ответы:**
#
#    - **Сильная положительная корреляция:**
#      - `Самая сильная положительная корреляция между переменными WT_50 и WT_62. Также сильная положительная корреляция наблюдается между переменными DBP_50 и SBP_50.`
#
#    - **Сильная отрицательная корреляция:**
#      - `Самая сильная отрицательная корреляция между переменными SBP_50 и CL_STATUS. Также сильная отрицательная корреляция наблюдается между переменными DBP_50 и CL_STATUS.`
#
#    - **Практически некоррелированные переменные:**
#      - `Практически не коррелируют: MD_50 и SBP_50, MD_50 и CL_STATUS, MD_50 и DBP_50, DBP_50 и DEATH, SES и DBP_62, IHD_DX и CL_STATUS.`

# %% [markdown]
# **Определите, какие переменные можно потенциально исключить из дальнейшего анализа из-за высокой корреляции:**
#
#    **Ваши ответы:**
#
#    - `Переменная CL_STATUS имеет в основном отрицательные корреляции, в том числе две самые больше отрицательные.`
